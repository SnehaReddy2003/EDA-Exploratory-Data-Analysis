# %% [markdown]
# # 05/11/2025

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path=r"C:\Users\SNEHA\OneDrive\Desktop\DS_My notes\categorical pro\VisaDataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=visa_df.select_dtypes(include=['object', 'category']).columns
num=visa_df.select_dtypes(exclude=['object', 'category']).columns

cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# ## prevailing_wage column

# %% [markdown]
# - min
#
# - max
#
# - count
#
# - mean
#
# - median

# %%
pwage=visa_df['prevailing_wage']

# %%
min(pwage)
# Out:
# 2.1367

# %%
max(pwage)
# Out:
# 319210.27

# %%
np.min(pwage)
# Out:
# 2.1367

# %%
np.max(pwage)
# Out:
# 319210.27

# %%
pwage.min()
# Out:
# 2.1367

# %%
np.mean(pwage)
# Out:
# 74455.81459209221

# %%
np.median(pwage)
# Out:
# 70308.20999999999

# %%
len(pwage) ## numpy -------> no count in numpy
# Out:
# 25480

# %%
pwage.count()     ## pandas
# Out:
# 25480

# %% [markdown]
# ## PERCENTILE -- QUARTILE

# %% [markdown]
# **percentile-25%**

# %%
np.percentile(pwage,25)        #calling data
# Out:
# 34015.479999999996

# %%
np.quantile(pwage,0.25)
# Out:
# 34015.479999999996

# %% [markdown]
# **percentile-50%**

# %%
np.percentile(pwage,50)
# Out:
# 70308.20999999999

# %%
np.quantile(pwage,0.50)
# Out:
# 70308.20999999999

# %% [markdown]
# **percentile-75%**

# %%
np.percentile(pwage,75)
# Out:
# 107735.51250000001

# %%
np.quantile(pwage,0.75)
# Out:
# 107735.51250000001

# %%
Count=pwage.count()
Min=np.min(pwage)
Max=np.max(pwage)

Mean=np.mean(pwage)
Median=np.median(pwage)
p_25=np.percentile(pwage,25)
p_50=np.percentile(pwage,50)
p_75=np.percentile(pwage,75)

# %%
metrics=[Count,Min,Max,Mean,Median,p_25,p_50,p_75]
ID=['Count','Min','Max','Mean','Median','p_25','p_50','p_75']
pd.DataFrame(metrics)
# Out:
#                0
# 0   25480.000000
# 1       2.136700
# 2  319210.270000
# 3   74455.814592
# 4   70308.210000
# 5   34015.480000
# 6   70308.210000
# 7  107735.512500

# %%
l=[]
for i in num:             #i=prevailing_wage'
    pwage=visa_df[i]
    Count=pwage.count()
    Min=np.min(pwage)
    Max=np.max(pwage)

    Mean=np.mean(pwage)
    Median=np.median(pwage)
    p_25=np.percentile(pwage,25)
    p_50=np.percentile(pwage,50)
    p_75=np.percentile(pwage,75)

    l.append(metrics)

# %%
pd.DataFrame(l)
# Out:
#        0       1          2             3         4         5         6  \
# 0  25480  2.1367  319210.27  74455.814592  70308.21  34015.48  70308.21
# 1  25480  2.1367  319210.27  74455.814592  70308.21  34015.48  70308.21
# 2  25480  2.1367  319210.27  74455.814592  70308.21  34015.48  70308.21
#
#              7
# 0  107735.5125
# 1  107735.5125
# 2  107735.5125

# %%
l=[]
for i in num:             #i=prevailing_wage'
    pwage=visa_df[i]
    Count=pwage.count()
    Min=np.min(pwage)
    Max=np.max(pwage)

    Mean=np.mean(pwage)
    Median=np.median(pwage)
    p_25=np.percentile(pwage,25)
    p_50=np.percentile(pwage,50)
    p_75=np.percentile(pwage,75)
    metrics=[Count,Min,Max,Mean,Median,p_25,p_50,p_75]
    
    l.append(metrics)

    
pd.DataFrame(l,columns=ID,index=num)
# Out:
#                  Count        Min        Max          Mean    Median  \
# no_of_employees  25480   -26.0000  602069.00   5667.043210   2109.00
# yr_of_estab      25480  1800.0000    2016.00   1979.409929   1997.00
# prevailing_wage  25480     2.1367  319210.27  74455.814592  70308.21
#
#                      p_25      p_50         p_75
# no_of_employees   1022.00   2109.00    3504.0000
# yr_of_estab       1976.00   1997.00    2005.0000
# prevailing_wage  34015.48  70308.21  107735.5125

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **percentile**
#
# - 25p=34015.48
#     - there is a 25 per of tatal data has values less than wages 34015.48
#
# - what is teh total data
#
#     - 25480
#
# - 25 per of total data
#
#     - 25480*25/100=6370
#
#    - there is 6370 employees has wages less than 34015.48

# %%
visa_df['prevailing_wage']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
#STEPS:

#1. call the toatl data frame
#2. data < p_25 ---------> 34015.48(hardcode)
#3. variable is cond

## Formula=Total * 25/100

# %% [markdown]
# - Formula=Total * 25/100

# %%
pwage=visa_df['prevailing_wage']
p_25=np.percentile(pwage,25)
visa_df['prevailing_wage'] < p_25

con=pwage < p_25
len(visa_df[con])
# Out:
# 6370

# %%
pwage=visa_df['prevailing_wage']
p_25=np.percentile(pwage,25)
visa_df['prevailing_wage'] < p_50

con=pwage < p_50
len(visa_df[con])
# Out:
# 12740

# %%
pwage=visa_df['prevailing_wage']
p_25=np.percentile(pwage,25)
visa_df['prevailing_wage'] < p_75

con=pwage < p_75
len(visa_df[con])
# Out:
# 19110

# %% [markdown]
# **Emperical Rule**

# %%
wage_mean=np.mean(pwage)

# %%
wage_std=np.std(pwage)

# %%
LB=Mean-1*wage_std
LB
# Out:
# 21640.908694978192

# %%
UB=Mean+1*wage_std
UB
# Out:
# 127270.72048920623

# %%
wage_mean=np.mean(pwage)
wage_std=np.std(pwage)
LB=wage_mean-1*wage_std
UB=wage_mean+1*wage_std

LB,UB
# Out:
# (21640.908694978192, 127270.72048920623)

# %%
wage_data=visa_df['prevailing_wage']
wage_mean=visa_df['prevailing_wage'].mean()
wage_std=visa_df['prevailing_wage'].std()
LB=wage_mean-1*wage_std
UB=wage_mean+1*wage_std

print(f'LB: {LB}')
print(f'LB: {UB}')

con1=wage_data > LB
con2=wage_data < UB

con= con1 & con2

len(visa_df[con])==99*25480/100
# Out:
# LB: 21639.87226521864
# LB: 127271.75691896578
# False

# %% [markdown]
# - Emperical Rule valid for Noraml Distribution
#
# - the above analysis conclude that, data does not follow normally

# %% [markdown]
# # 08/12/2025

# %% [markdown]
# ## Histogram

# %%
wage_data=visa_df['prevailing_wage']

plt.hist(wage_data)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# - the graph is Left Skew----> the distribution is towards left

# %%
wage_data=visa_df
f,values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 2>()
#       1 wage_data=visa_df
# ----> 2 f,values
#
# NameError: name 'f' is not defined

# %%
values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 values
#
# NameError: name 'values' is not defined

# %%
f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 f
#
# NameError: name 'f' is not defined

# %%
# there are 6038 applicants has wages b/w 2.1367 to 31922.95 dollars
2.13670000e+00,3.19229500e+04
# Out:
# (2.1367, 31922.95)

# %%
wage_data=visa_df['prevailing_wage']
lb=2.13670000e+00
ub=3.19229500e+04
con1 = wage_data>lb
con2 = wage_data<ub
con3=con1 & con2              # should match using &
len(visa_df[con3])
# Out:
# 6037

# %% [markdown]
# - we understand the percentile
#
# - we explore the emperical rule
#
# - then emperical rule failed
#
# - that means the data does not follow normal distribution
#
# - we also checked with histogram plot
#
# - histogram plot also supported our research: data does not follow normality
#
# - it has Right skew,so that some outliers present
#
# - we need to visualize those outliers bu using BOXPLOT

# %% [markdown]
# # BOX PLOT

# %%
wage_data=visa_df['prevailing_wage']

plt.boxplot(wage_data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x252abc072e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x252abb52310>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x252abab61c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x252abab4640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x252abab4940>],
#  'means': []}

# %%
plt.boxplot(wage_data)
plt.show()

# %%
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
# outliers can match any side ---> either right or left
#or can be both sides 
# use OR

# %%
#step-1:q1
#S-2:   q2
#S-3:    q3
#S-4:   iqr=q3-q1
#S-5: lb=q1-1.5*iqr
#S-6: ub=q3-1.5*iqr
#S-7:  con1
#S-8:  con2
#S-9:  con(or)
#S-10: get the count

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
con1=wage_data<lb
con2=wage_data>ub
con3=con1 | con2
len(visa_df[con3])
# Out:
# 427

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
con1=wage_data<lb
con2=wage_data>ub
con3=con1 | con2
len(visa_df[con3])
outliers_df=visa_df[con3]
outliers_df['prevailing_wage']
# Out:
# 14       220081.73
# 34       225569.73
# 130      247393.01
# 216      269321.68
# 221      219529.62
#            ...
# 25191    280482.51
# 25195    234308.77
# 25468    272715.74
# 25469    273772.47
# 25476    279174.79
# Name: prevailing_wage, Length: 427, dtype: float64

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
con1=wage_data<lb
con2=wage_data>ub
con3=con1 | con2
len(visa_df[con3])
outliers_df=visa_df[con3]
outliers_df['prevailing_wage'].values
# Out:
# array([220081.73, 225569.73, 247393.01, 269321.68, 219529.62, 232227.33,
#        238691.32, 220448.17, 230750.48, 235339.91, 232680.65, 256261.78,
#        262189.  , 250510.67, 218554.78, 256205.38, 221944.22, 229950.7 ,
#        222628.84, 229819.69, 233641.72, 274019.43, 218982.83, 230984.28,
#        223128.23, 246705.  , 240266.34, 226090.72, 231949.27, 254604.08,
#        288318.91, 244457.48, 242146.48, 247545.23, 234139.17, 231834.72,
#        222730.57, 239773.63, 220553.95, 237539.32, 266440.49, 277281.01,
#        275627.59, 249291.12, 292106.59, 234012.11, 247009.24, 267726.09,
#        222098.09, 280661.13, 277984.52, 262852.71, 263877.21, 230916.64,
#        264760.64, 267868.56, 222221.67, 242406.32, 276894.08, 281832.93,
#        221033.57, 258292.84, 223492.85, 245418.67, 250289.08, 271344.69,
#        252825.11, 230843.7 , 253668.86, 245819.17, 239465.3 , 236316.36,
#        225268.13, 228941.33, 306021.96, 228074.25, 270799.93, 221982.69,
# ...

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
con1=wage_data<lb
con2=wage_data>ub
con3=con1 | con2
len(visa_df[con3])
outliers_df=visa_df[con3]

outliers_df['prevailing_wage'].values
outliers_list=outliers_df['prevailing_wage'].values.tolist()

# %%
# i want to call the each observation of wagedata
# if that observations will available in this 427 values
# the that observation will replace by median
# otherwise that observation  will be available as it is



wage_median=visa_df['prevailing_wage'].median()
wage_median=visa_df['prevailing_wage']
new_wage_data=[]
for i in wage_data:
    if i in  outliers_list:
        new_wage_data.append(wage_median)
    else:
        new_wage_data.append(i)

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <AxesSubplot:>

# %%
plt.subplot(2,2,1)
plt.hist(wage_data)

plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <AxesSubplot:>

# %%
plt.subplot(2,2,1)
plt.hist(wage_data)

plt.subplot(2,2,2)
plt.hist(new_wage_data)

plt.subplot(2,2,3)
plt.boxplot(wage_data,vert=False)

plt.subplot(2,2,4)
plt.boxplot(new_wage_data,vert=False)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1).hist(wage_data)

plt.subplot(2,2,2).hist(wage_data_clip)

plt.subplot(2,2,3).boxplot(wage_data,vert=False)

plt.subplot(2,2,4).boxplot(wage_data_clip,vert=False)
plt.show()

# %% [markdown]
# **Winsorisation**

# %% [markdown]
# - whatever the outliers less than

# %%
#S-1: set the wages data
#S-2: calculate lb
#S-3: calculate ub
#S-4: check the parameter and appply in numpy np.clip()
#S-5: again implement above visualisation analysis


wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
wage_data_clip=np.clip(wage_data,lb,ub)

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1).hist(wage_data_clip)

plt.subplot(2,2,2).hist(new_wage_data_clip)

plt.subplot(2,2,3).boxplot(wage_data,vert=False)

plt.subplot(2,2,4).boxplot(new_wage_data_clip,vert=False)
plt.show()
